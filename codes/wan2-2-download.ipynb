# %%
import os

# 1. Set up the shared download directory
save_path = "/kaggle/working/models_download"
os.makedirs(save_path, exist_ok=True)

print(f"🚀 Starting final download script Wan 2.2 5B Q8 ...")

# ======================================================
# Wan 2.2 TI2V-5B Video Group (For animating images)
# ======================================================

# 2. Wan 2.2 5B Model (GGUF Q6_K)

# Sourced from QuantStack, approx 4.1GB, perfect for 16GB VRAM.
# !wget -c https://huggingface.co/QuantStack/Wan2.2-TI2V-5B-GGUF/resolve/main/Wan2.2-TI2V-5B-Q6_K.gguf -P {save_path}

# 3. Turbo Q8_0
# !wget -c https://huggingface.co/hum-ma/Wan2.2-TI2V-5B-Turbo-GGUF/resolve/main/Wan2_2-TI2V-5B-Turbo-Q8_0.gguf -P {save_path}
# !wget -c https://huggingface.co/hum-ma/Wan2.2-TI2V-5B-Turbo-GGUF/resolve/main/Wan22_TI2V_5B_Turbo_lora_rank_64_fp16.safetensors -P {save_path}

# 4. Wan Specific VAE (Comfy-Org repackaged version for best compatibility)
# !wget -c https://huggingface.co/QuantStack/Wan2.2-TI2V-5B-GGUF/resolve/main/VAE/Wan2.2_VAE.safetensors -P {save_path}

# 5. UMT5 Text Encoder (FP8)
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors -P {save_path}

# 6. Clip Vision
# Wan uses ViT-H (clip_vision_h), essential for Image-to-Video.
# !wget -c https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/clip_vision/clip_vision_h.safetensors -P {save_path}


print("✅ All downloads completed!")
print("--------------------------------------------------")
print("【ComfyUI File Mapping Reference (Important)】")
print("1. Wan2.2-TI2V-5B-Q8_K.gguf  -> models/unet (Must use GGUF Loader)")
print("2. Wan2.2-TI2V-5B-Turbo-Q8_K.gguf  -> models/unet (Must use GGUF Loader)")
print("3. wan_2.1_vae.safetensors   -> models/vae")
print("4. umt5_xxl_fp8...           -> models/text_encoders")
print("5. clip_vision_h.safetensors -> models/clip_vision (Note: inside clip_vision folder)")
