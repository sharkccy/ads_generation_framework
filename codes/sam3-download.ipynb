# %%
import os

# 1. Set up the shared download directory
save_path = "/kaggle/working/models_download"
os.makedirs(save_path, exist_ok=True)

print(f"🚀 Starting SAM3.1 model download ...")

# ======================================================
# A. SAM 3.1 Model (Only the main checkpoint)
# ======================================================

# !wget -c https://huggingface.co/Comfy-Org/sam3.1/resolve/main/checkpoints/sam3.1_multiplex_fp16.safetensors -P {save_path}

print("✅ SAM3.1 model download completed!")
print("--------------------------------------------------")
print("【ComfyUI File Mapping Reference】")
print("sam3.1_multiplex_fp16.safetensors -> models/sam")
